# %%
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
! cargo run --release > goy.csv
# Out:
#    Compiling goy_shell v0.1.0 (C:\Users\mtta2\Desktop\Desktop\2_Programming\Rust\numerical\goy_shell)
#     Finished release [optimized] target(s) in 1.37s
#      Running `target\release\goy_shell.exe`

# %%
df = pd.read_csv("goy.csv").set_index("time")

# %%
df[["r4", "r8", "r16", "r26"]].plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
(df**2).mean().plot()
plt.yscale("log")
